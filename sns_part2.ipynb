# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
iris = sns.load_dataset('iris')
sns.lmplot(x = "sepal_width",y='sepal_length',hue='species',data=iris)

# %%
sns.lmplot(x = "sepal_width",y='petal_length',hue='species',data=iris)

# %%
h = sns.PairGrid(iris)
h = h.map(plt.scatter)
sns.pairplot(iris)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# *JOINT GRID and JOINT PLOT

# %%
uniform_data = np.random.rand(10,12)
data = pd.DataFrame({'x':np.arange(1,101),
                     'y':np.random.normal(0,4,100)})
data
i = sns.JointGrid(x="x",y="y",data=data)
i = i.plot(sns.regplot, sns.distplot)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
# ...

# %%
sns.jointplot("sepal_length","sepal_width",data=iris,kind='kde')
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("sepal_length","petal_width",data=iris)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("sepal_length","species",data=iris)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("petal_length","petal_width",data=iris)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("petal_length","petal_width",data=iris,kind='kde')
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset('titanic')
sns.violinplot(x='age',y='sex',hue='survived',data=titanic)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic = sns.load_dataset('titanic')
sns.violinplot(x='age',y='sex',hue='class',data=titanic)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.boxplot(x='alive',y='age',hue='adult_male',data=titanic)
# Out:
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %%
sns.boxplot(y='alive',x='age',hue='adult_male',data=titanic)
# Out:
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.boxplot(y='alive',x='age',hue='adult_male',orient='h',data=titanic)
# Out:
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.violinplot(x='alive',y='age',hue='adult_male',data=titanic)
# Out:
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %%
sns.boxplot(data=iris,orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=titanic,orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.pointplot(x='class',y='survived',hue='sex',data=titanic,palette={"male":"g","female":"m"},
              markers=["^","o"],linestyles=["-","--"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.pointplot(x='class',y='survived',hue='sex',data=titanic,palette={"male":"g","female":"m"},
              markers=["d","."],linestyles=["dashed","dashdot"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.countplot(x='deck',data=titanic,palette="Greens_d")
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
sns.countplot(x='deck',data=titanic,palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
sns.barplot(x="sex",y="survived",hue="class",data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.barplot(x="sex",y="survived",hue="deck",data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.stripplot(x='species',y='petal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.stripplot(x='species',y='petal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.stripplot(x='species',y='sepal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x='species',y='petal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.swarmplot(x='species',y='petal_length',data=iris)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.swarmplot(x='species',y='petal_width',data=iris)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.swarmplot(x='species',y='sepal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(x='species',y='sepal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.distplot(iris.sepal_width, kde=True,color='b')
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %%
data.head()
# Out:
#    x         y
# 0  1  0.527602
# 1  2 -0.583615
# 2  3  3.749634
# 3  4 -1.659481
# 4  5 -1.299776

# %%
sns.distplot(data.x, kde=True,color='b')
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='x', ylabel='Density'>

# %%
sns.heatmap(uniform_data,vmin=0,vmax=1)
plt.savefig("foo.png")
plt.savefig("foo.jpg")
plt.savefig("foo.raw")

# %% [markdown]
# # supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff)

# %%
sns.heatmap(titanic,vmin=0,vmax=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kg/xq7xr8t15l555m9hcznhw4140000gq/T/ipykernel_59509/1142168324.py in <module>
# ----> 1 sns.heatmap(titanic,vmin=0,vmax=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...
