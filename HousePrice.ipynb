# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
house = pd.read_csv('house.csv')

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.shape
# Out:
# (1460, 81)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
house.LotFrontage.describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
house.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(x=house.SalePrice)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.heatmap(house.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(30,30)
plt.show()

# %%
# the above map is difficult to read. We need to reduce some columns. 

# first, let's compare saleprice to other variables that are also continuous

# %%
sns.swarmplot(data=house,y=house.PavedDrive,x=house.SalePrice)
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 75.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='PavedDrive'>

# %%
#Paved Drive - most houses have paved drive and houses with paved drive seem to have gone for higher prices

# %%
sns.scatterplot(x=house.SalePrice,y=house.LotArea)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
#Lot area and SalePrice does not seem to have a direct correlation

# %%
sns.scatterplot(x=house.SalePrice,y=house.LotFrontage)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotFrontage'>

# %%
sns.stripplot(x=house.SalePrice,y=house.MSZoning)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='MSZoning'>

# %%
sns.scatterplot(x=house.SalePrice,y=house.LotArea,hue=house.MSZoning)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
f ,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=house.SalePrice,y=house.LotArea,hue=house.MSSubClass)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
# To get a better picture, let's drop values where Lot Area is greated than 50000

# %%
f ,ax = plt.subplots(figsize=(10,10))
house1 = house[house['LotArea']<=50000]
sns.scatterplot(x=house1.SalePrice,y=house1.LotArea,hue=house.MSSubClass)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
#After dropping the outlier values, we clearly see correlation between SalePrice and LotArea
#Let's see this with MSZoning

# %%
f ,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=house1.SalePrice,y=house1.LotArea,hue=house.MSZoning)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
f ,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=house1.SalePrice,y=house1.LotArea,hue=house.LotShape)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
# (Assuming that IR1, IR2,IR3 stand for irregular shape,)
# Regular shape prices and lot area are generally lesser compared to irregularly shaped lots
#But, within the same lot area, the shape does not seem to have an influence on the price

# %%
f ,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=house1.SalePrice,y=house1.Functional,hue=house.Fireplaces)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Functional'>

# %%
sns.stripplot(x=house1.SalePrice,y=house1.GarageType)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='GarageType'>

# %%
sns.scatterplot(x=house1.SalePrice,y=house1.GarageArea)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='GarageArea'>

# %%
# Garage area is directly linked to price of the house

# %%
sns.scatterplot(x=house1.SalePrice,y=house1.PoolArea)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='PoolArea'>

# %%
# Most entries don't have pool

# %%
sns.scatterplot(x=house1.SalePrice,y=house1.YrSold)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='YrSold'>

# %%
sns.scatterplot(x=house1.YrSold,y=house1.SalePrice,hue=house1.LotArea)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %%
f ,ax = plt.subplots(figsize=(20,10))
sns.scatterplot(x=house1.LotArea,y=house1.SalePrice,size=house1.LotArea)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.scatterplot(y=house1.BldgType,x=house1.SalePrice,hue=house1.LotArea)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='BldgType'>

# %%
f ,ax = plt.subplots(figsize=(20,20))
sns.violinplot(y=house1.BldgType,x=house1.SalePrice,hue=house1.MSZoning)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='BldgType'>

# %%
f ,ax = plt.subplots(figsize=(20,20))
sns.boxplot(y=house1.BldgType,x=house1.SalePrice,hue=house1.MSZoning)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='BldgType'>

# %%
f ,ax = plt.subplots(figsize=(20,20))
sns.boxplot(x=house1.BldgType,y=house1.SalePrice,hue=house1.MSZoning)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='SalePrice'>

# %%
# Tehre are lot of outliers in the 1Fam building type.. let's remove any house with saleproce above 350000

# %%
f ,ax = plt.subplots(figsize=(15,10))
house2 = house1[house1['SalePrice']<=350000]
sns.boxplot(x=house2.BldgType,y=house2.SalePrice,hue=house2.MSZoning)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='SalePrice'>

# %%
# The RM zone houses seem to the closely pplaced in price irrespective of the type of building.
# Let's look at the area for the same

# %%
sns.boxplot(x=house2.BldgType,y=house2.LotArea,hue=house2.MSZoning)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='LotArea'>

# %%
# Lot area also has huge amount of outliers
# Let's see how many are there

# %%
len(house2[house2['LotArea']>=18000])
# Out:
# 47

# %%
# Tehre are 47 items greater that lot area of 18000.
# Let's drop these as outliers or rather create a new df only with values less than 18000 lot area

# %%
f ,ax = plt.subplots(figsize=(15,10))
house3 = house2[house2['LotArea']<=18000]
sns.boxplot(x=house3.BldgType,y=house3.LotArea,hue=house3.MSZoning)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='LotArea'>

# %%
# Let's see a violin plot to understand the distribution better

# %%
f ,ax = plt.subplots(figsize=(15,6))
sns.violinplot(x=house3.BldgType,y=house3.LotArea,hue=house3.MSZoning)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='LotArea'>

# %%
f ,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=house3.SalePrice,y=house3.LotArea,hue=house3.MSZoning)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
# we need to see a few different views before making a meaningful inference
# let's try stripplot

# %%
f ,ax = plt.subplots(figsize=(10,10))
sns.stripplot(x=house3.MSZoning,y=house3.LotArea)
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='LotArea'>

# %% [markdown]
# h = sns.PairGrid(house3)
# h = h.map(plt.scatter)
# sns.pairplot(house3)

# %%
# Thats one crazy pair grid
# based on analysis made above, let's stick the key columns only

# %%
house3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1352 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1352 non-null   int64
#  1   MSSubClass     1352 non-null   int64
#  2   MSZoning       1352 non-null   object
#  3   LotFrontage    1121 non-null   float64
#  4   LotArea        1352 non-null   int64
#  5   Street         1352 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1352 non-null   object
#  8   LandContour    1352 non-null   object
#  9   Utilities      1352 non-null   object
#  10  LotConfig      1352 non-null   object
#  11  LandSlope      1352 non-null   object
#  12  Neighborhood   1352 non-null   object
#  13  Condition1     1352 non-null   object
#  14  Condition2     1352 non-null   object
#  15  BldgType       1352 non-null   object
#  16  HouseStyle     1352 non-null   object
# ...

# %%
house4 = house3.drop(['WoodDeckSF','Id','BsmtFinSF2','BsmtUnfSF','BsmtFinSF1','BsmtFinSF2','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath','OverallQual','OverallCond','YearBuilt','YearRemodAdd','GarageCars','GarageArea','OpenPorchSF','EnclosedPorch','3SsnPorch','PoolArea','MiscVal','MoSold','YrSold','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageYrBlt'],axis='columns')
house4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1352 entries, 0 to 1459
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1352 non-null   int64
#  1   MSZoning       1352 non-null   object
#  2   LotFrontage    1121 non-null   float64
#  3   LotArea        1352 non-null   int64
#  4   Street         1352 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1352 non-null   object
#  7   LandContour    1352 non-null   object
#  8   Utilities      1352 non-null   object
#  9   LotConfig      1352 non-null   object
#  10  LandSlope      1352 non-null   object
#  11  Neighborhood   1352 non-null   object
#  12  Condition1     1352 non-null   object
#  13  Condition2     1352 non-null   object
#  14  BldgType       1352 non-null   object
#  15  HouseStyle     1352 non-null   object
#  16  RoofStyle      1352 non-null   object
# ...

# %%
f ,ax = plt.subplots(figsize=(20,20))
h = sns.PairGrid(house4)
h = h.map(plt.scatter)
sns.pairplot(house4)

# %%
sns.scatterplot(data=house4,y=house4.LotFrontage,x=house4.SalePrice,hue=house4.TotalBsmtSF)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotFrontage'>

# %%
sns.scatterplot(data=house4,y=house4.LotFrontage,x=house4.SalePrice,hue=house4.LotArea)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotFrontage'>

# %%
sns.scatterplot(data=house4,y=house4.TotalBsmtSF,x=house4.SalePrice,hue=house4.LotArea)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='TotalBsmtSF'>

# %%
# Total Bsmt Area, LotFrontage adds up to the overall LotArea
# We can clearly see as these areas go up, the price also tends to go up

# %%
sns.scatterplot(data=house4,y=house4.LotArea,x=house4.SalePrice,hue=house4.ScreenPorch)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
# Screen porch is also directly related to increase in sale price
# but in the overall set, there are minimal entries with screen porch >0

# %%
# Lot Area is the primary factor in determining the saleprice.
# Let's do a lm plot for the same

# %%
sns.lmplot(x = "SalePrice",y='LotArea',hue='MSZoning',data=house4)

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
#dependent Variable
Y=house4['SalePrice']
# independent Variable
X=house4['LotArea']
#Adding constant                        
X=sm.add_constant(X)
simple=sm.OLS(Y,X)
result=simple.fit()
result.summary()
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     239.4
# Date:                Mon, 11 Apr 2022   Prob (F-statistic):           7.71e-50
# Time:                        08:17:29   Log-Likelihood:                -16686.
# No. Observations:                1352   AIC:                         3.338e+04
# Df Residuals:                    1350   BIC:                         3.339e+04
# Df Model:                           1
# ...

# %%
# The RSquare value is only .15. We need to add more variables to see if we can improve this. Let's try adding Total Bsmn SF

# %%
#dependent Variable
Y=house4['SalePrice']
# independent Variable
X=house4[['LotArea', 'TotalBsmtSF']]
#Adding constant                        
X=sm.add_constant(X)
simple=sm.OLS(Y,X)
result=simple.fit()
result.summary()
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     448.6
# Date:                Mon, 11 Apr 2022   Prob (F-statistic):          4.26e-150
# Time:                        08:19:26   Log-Likelihood:                -16452.
# No. Observations:                1352   AIC:                         3.291e+04
# Df Residuals:                    1349   BIC:                         3.293e+04
# Df Model:                           2
# ...

# %%
house4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1352 entries, 0 to 1459
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1352 non-null   int64
#  1   MSZoning       1352 non-null   object
#  2   LotFrontage    1121 non-null   float64
#  3   LotArea        1352 non-null   int64
#  4   Street         1352 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1352 non-null   object
#  7   LandContour    1352 non-null   object
#  8   Utilities      1352 non-null   object
#  9   LotConfig      1352 non-null   object
#  10  LandSlope      1352 non-null   object
#  11  Neighborhood   1352 non-null   object
#  12  Condition1     1352 non-null   object
#  13  Condition2     1352 non-null   object
#  14  BldgType       1352 non-null   object
#  15  HouseStyle     1352 non-null   object
#  16  RoofStyle      1352 non-null   object
# ...

# %%
# The R squared value is improved to .39. We still need to find better ways. Let's try adding ScreenPorch

#dependent Variable
Y=house4['SalePrice']
# independent Variable
X=house4[['LotArea', 'TotalBsmtSF','ScreenPorch']]
#Adding constant                        
X=sm.add_constant(X)
simple=sm.OLS(Y,X)
result=simple.fit()
result.summary()
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     300.1
# Date:                Mon, 11 Apr 2022   Prob (F-statistic):          3.25e-149
# Time:                        08:30:37   Log-Likelihood:                -16451.
# No. Observations:                1352   AIC:                         3.291e+04
# Df Residuals:                    1348   BIC:                         3.293e+04
# Df Model:                           3
# ...

# %%
# can we add MSSubcalss

# The R squared value is improved to .39. We still need to find better ways. Let's try adding ScreenPorch

#dependent Variable
Y=house4['SalePrice']
# independent Variable
X=house4[['LotArea', 'TotalBsmtSF','ScreenPorch','MSSubClass']]
#Adding constant                        
X=sm.add_constant(X)
simple=sm.OLS(Y,X)
result=simple.fit()
result.summary()
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.437
# Method:                 Least Squares   F-statistic:                     262.7
# Date:                Mon, 11 Apr 2022   Prob (F-statistic):          6.18e-167
# Time:                        08:31:39   Log-Likelihood:                -16407.
# No. Observations:                1352   AIC:                         3.282e+04
# Df Residuals:                    1347   BIC:                         3.285e+04
# Df Model:                           4
# ...

# %%
# the R squared value is now .43. Still not good enough
house5 = house4.dropna(subset =['LotFrontage'])
house5.info()
house4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1121 entries, 0 to 1459
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1121 non-null   int64
#  1   MSZoning       1121 non-null   object
#  2   LotFrontage    1121 non-null   float64
#  3   LotArea        1121 non-null   int64
#  4   Street         1121 non-null   object
#  5   Alley          86 non-null     object
#  6   LotShape       1121 non-null   object
#  7   LandContour    1121 non-null   object
#  8   Utilities      1121 non-null   object
#  9   LotConfig      1121 non-null   object
#  10  LandSlope      1121 non-null   object
#  11  Neighborhood   1121 non-null   object
#  12  Condition1     1121 non-null   object
#  13  Condition2     1121 non-null   object
#  14  BldgType       1121 non-null   object
#  15  HouseStyle     1121 non-null   object
#  16  RoofStyle      1121 non-null   object
# ...

# %%
# lets add lot frontage after cleaning the Nan values


#dependent Variable
Y=house5['SalePrice']
# independent Variable
X=house5[['LotArea', 'TotalBsmtSF','MSSubClass','LotFrontage']]
#Adding constant                        
X=sm.add_constant(X)
simple=sm.OLS(Y,X)
result=simple.fit()
result.summary()
# Out:
# /Users/sunshankar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     244.0
# Date:                Mon, 11 Apr 2022   Prob (F-statistic):          1.37e-150
# Time:                        08:45:35   Log-Likelihood:                -13606.
# No. Observations:                1121   AIC:                         2.722e+04
# Df Residuals:                    1116   BIC:                         2.725e+04
# Df Model:                           4
# ...

# %%
# the R Square is still around .46 only.

# %%
# lets add MasVnRAre after cleaning the Nan values
house6 = house5.dropna(subset =['MasVnrArea'])
house6.info()


#dependent Variable
Y=house6['SalePrice']
# independent Variable
X=house6[['LotArea', 'TotalBsmtSF','MSSubClass','LotFrontage','MasVnrArea']]
#Adding constant                        
X=sm.add_constant(X)
simple=sm.OLS(Y,X)
result=simple.fit()
result.summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1116 entries, 0 to 1459
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1116 non-null   int64
#  1   MSZoning       1116 non-null   object
#  2   LotFrontage    1116 non-null   float64
#  3   LotArea        1116 non-null   int64
#  4   Street         1116 non-null   object
#  5   Alley          85 non-null     object
#  6   LotShape       1116 non-null   object
#  7   LandContour    1116 non-null   object
#  8   Utilities      1116 non-null   object
#  9   LotConfig      1116 non-null   object
#  10  LandSlope      1116 non-null   object
#  11  Neighborhood   1116 non-null   object
#  12  Condition1     1116 non-null   object
#  13  Condition2     1116 non-null   object
#  14  BldgType       1116 non-null   object
#  15  HouseStyle     1116 non-null   object
#  16  RoofStyle      1116 non-null   object
# ...

# %%
# Now, we have improved the R Square value to .50,
